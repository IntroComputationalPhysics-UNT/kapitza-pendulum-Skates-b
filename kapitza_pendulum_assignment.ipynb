# %% [markdown]
# <a href="https://colab.research.google.com/github/IntroComputationalPhysics-UNT/kapitza-pendulum-Skates-b/blob/main/kapitza_pendulum_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Overview & Psuedocode:**
# ---
#
# Overall objectives for this assignment:
#
# 1. Design our own stability diagnostic for this pendulum.
# 2. Map the long-time behavior vs the parameters.
# 3. Produce a 2D stability plot.
#
# ---
# Psuedocode:
# 1. **Install the needed libraries/databases:** Install `numpy as np`, `matplotlib.pyplot as plt`, and `from scipy.integration install solve_ivp`.
# 2. **Define all our utilities and parameters:**
# We will define a function for the equation of motion for the kapitza pendulum called `kapitza_pen` with parameters: $$\tau, y, \epsilon, \alpha, \zeta$$ using the dimensionlesss equation of motion:
# $$\theta" + 2 \zeta \theta ' + (\epsilon ^2 - \alpha cos(\tau)) sin(\theta) = 0$$
# or
# $$\theta'' = -2 \zeta \theta' - (\epsilon^2 - \alpha cos(\tau))sin(\theta)$$
#
# We'll also define a function to find the bounadies of the inverted space: holding `ζ` and `ϵ` cosntant while sweeping `α`.
#
# 3. **Define our equation of motion for Kapitza:**
#
# 4. **Design a stability diagnostic:**
# 5. **Map the long-time behavior vs the parameters:**
# 6. **Produce a 2D stability plot:**
#
# ---
# **To be sorted and explained nicely:**
#
# $$\theta" + 2 \zeta \theta ' + (\epsilon ^2 - \alpha cos(\tau)) sin(\theta) = 0$$
#
# *This equation is dimensionless.
#
# $$\epsilon = \frac{\omega_0}{\omega_d}$$
#
# $$\alpha = \frac{y_0}{l}$$
#
# $$\zeta = \frac{\gamma}{\omega_d}$$
#
# *These three numbers are constant. Inputs -> outputs of behavior at large tau
#
# $$\theta ' = \frac{d \theta}{d \tau}$$
#
# $$\tau = \omega_d t$$
#
# Goal: Numerically explore which combinations of $$(\epsilon, \alpha, \zeta)$$ the inverted state $$\theta = \pi$$ becomes stable.
#
# We can hold one value to be constant and sweep through the other two until we get something sensible.
#
# $$\omega_0 = \sqrt{\frac{g}{l}}$$
